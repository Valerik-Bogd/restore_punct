# %% [markdown]
# # 99_aggregate_master_table
#
# Rebuilds `results/master_summary.xlsx` from `results/models_db.json` and `results/yandex_db.json`. Idempotent — run it whenever you want to refresh the combined table without retraining anything.

# %%
import os, sys
_here = os.path.abspath(os.getcwd())
_root = _here if os.path.isdir(os.path.join(_here, 'pipeline')) else os.path.abspath(os.path.join(_here, os.pardir))
if _root not in sys.path:
    sys.path.insert(0, _root)
os.chdir(_root)

from pipeline.aggregate import rebuild_master_excel
rebuild_master_excel()
